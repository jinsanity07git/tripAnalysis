# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
import os
try:
	os.chdir(os.path.join(os.getcwd(), 'tripAnalysis'))
	print(os.getcwd())
except:
	pass

# %%
import pandas as pd
fname= '2017Prowl_condense.csv'
path = 'Data/'
df_raw = pd.read_csv(path+ fname,index_col='Unhashed card ID')
df_raw.head(10)
df_raw.columns
"""
Index(['Date', 'Time', 'Stop', 'OnOffCam'], dtype='object')
"""



Stud_ID = df_raw.index.unique()
len(Stud_ID)  #7572

stud = 8
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# /Users/jinsanity/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# OnOffCam  Stop
# 0         Cunningham Hall (Cunn)                       3
#           Non-Peak Hours UWM KIRC (KIRC-S)             2
#           Sandburg Residence Hall (Sand)               4
#           UWM Golda Meir Library (Lib)                23
# 1         Capitol and Humboldt Park and Ride (C/H)     1
#           RiverView Residence Hall (RVW)              25
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0    32
# 1    26
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Cunningham Hall (Cunn)                       3
#           Non-Peak Hours UWM KIRC (KIRC-S)             2
#           Sandburg Residence Hall (Sand)               4
#           UWM Golda Meir Library (Lib)                23
# 1         Capitol and Humboldt Park and Ride (C/H)     1
#           RiverView Residence Hall (RVW)              25
# Name: Date, dtype: int64

# %%
stud = 80
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Non-Peak Hours UWM KIRC (KIRC-S)          3
#           Sandburg Residence Hall (Sand)           12
#           UWM Golda Meir Library (Lib)             52
# 1         Cambridge Commons (CC-S)                 38
#           Cambridge Commons - Northbound (CC-N)     2
#           RiverView Residence Hall (RVW)            1
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0    67
# 1    41
# Name: Date, dtype: int64

# %%
stud = 180
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Non-Peak Hours UWM KIRC (KIRC-S)             2
#           Sandburg Residence Hall (Sand)              34
#           UWM Union (Union)                            2
# 1         Capitol and Humboldt Park and Ride (C/H)    31
#           Kenilworth Square Apartments (KNW)           1
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0    38
# 1    32
# Name: Date, dtype: int64

# %%
stud = 280
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Sandburg Residence Hall (Sand)               3
#           UWM Golda Meir Library (Lib)                 1
#           UWM Union (Union)                           28
# 1         Capitol and Humboldt Park and Ride (C/H)    23
#           Kenilworth Square Apartments (KNW)           2
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0    32
# 1    25
# Name: Date, dtype: int64

# %%
stud = 380
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Non-Peak Hours UWM KIRC (KIRC-S)             8
#           Sandburg Residence Hall (Sand)               6
#           UWM Union (Union)                           27
# 1         Capitol and Humboldt Park and Ride (C/H)    26
#           Kenilworth Square Apartments (KNW)           1
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0    41
# 1    27
# Name: Date, dtype: int64

# %%
Stud_ID = df_raw.index.unique()
len(Stud_ID)  #7572

stud = 380
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Non-Peak Hours UWM KIRC (KIRC-S)             8
#           Sandburg Residence Hall (Sand)               6
#           UWM Union (Union)                           27
# 1         Capitol and Humboldt Park and Ride (C/H)    26
#           Kenilworth Square Apartments (KNW)           1
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0    41
# 1    27
# Name: Date, dtype: int64

# %%
tud = 480
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Non-Peak Hours UWM KIRC (KIRC-S)             8
#           Sandburg Residence Hall (Sand)               6
#           UWM Union (Union)                           27
# 1         Capitol and Humboldt Park and Ride (C/H)    26
#           Kenilworth Square Apartments (KNW)           1
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0    41
# 1    27
# Name: Date, dtype: int64

# %%
stud = 580
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Non-Peak Hours UWM KIRC (KIRC-S)             3
#           Sandburg Residence Hall (Sand)               1
#           UWM Union (Union)                           31
# 1         Cambridge Commons - Northbound (CC-N)        1
#           Capitol and Humboldt Park and Ride (C/H)    30
#           Kenilworth Square Apartments (KNW)           1
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0    35
# 1    32
# Name: Date, dtype: int64

# %%
stud = 680
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Cunningham Hall (Cunn)                       4
#           Non-Peak Hours UWM KIRC (KIRC-S)             3
#           Sandburg Residence Hall (Sand)               2
#           UWM Golda Meir Library (Lib)                 1
#           UWM Union (Union)                           18
# 1         Cambridge Commons - Northbound (CC-N)        1
#           Capitol and Humboldt Park and Ride (C/H)    23
#           Kenilworth Square Apartments (KNW)           3
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0    28
# 1    27
# Name: Date, dtype: int64

# %%
stud = 780
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Cunningham Hall (Cunn)                       2
#           Non-Peak Hours UWM KIRC (KIRC-S)             2
#           Sandburg Residence Hall (Sand)               5
#           UWM Golda Meir Library (Lib)                44
# 1         Cambridge Commons (CC-S)                    50
#           Cambridge Commons - Northbound (CC-N)        7
#           Capitol and Humboldt Park and Ride (C/H)     2
#           Kenilworth Square Apartments (KNW)           4
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0    53
# 1    63
# Name: Date, dtype: int64

# %%
stud = 880
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Cunningham Hall (Cunn)                   25
#           Non-Peak Hours UWM KIRC (KIRC-S)          1
#           Sandburg Residence Hall (Sand)            1
#           UWM Golda Meir Library (Lib)              5
#           UWM Union (Union)                         1
# 1         Cambridge Commons - Northbound (CC-N)     1
#           Kenilworth Square Apartments (KNW)       43
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0    33
# 1    44
# Name: Date, dtype: int64

# %%
stud = 980
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Cunningham Hall (Cunn)                    9
#           Non-Peak Hours UWM KIRC (KIRC-S)          4
#           Sandburg Residence Hall (Sand)            5
#           UWM Golda Meir Library (Lib)             14
# 1         Cambridge Commons (CC-S)                 23
#           Cambridge Commons - Northbound (CC-N)     1
#           Kenilworth Square Apartments (KNW)        2
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0    32
# 1    26
# Name: Date, dtype: int64

# %%
stud = 1080
df_person = df_raw[df_raw.index == Stud_ID[stud] ]
# df_person.groupby(['OnOffCam','Stop','Date']).count()

# weekdays categorization
# #####df_person.groupby(['Weekday','OnOffCam','Stop'])['Date'].count()
df_person.groupby(['Weekday','Stop','OnOffCam'])['Date'].count()

# subtotal---- On Campus count summation
df_person.groupby(['OnOffCam'])['Date'].count()

# OD Infering---- On-off Campus
df_person.groupby(['OnOffCam','Stop'])['Date'].count()
# Out:
# OnOffCam  Stop
# 0         Sandburg Residence Hall (Sand)         2
#           UWM Golda Meir Library (Lib)           7
# 1         Cambridge Commons (CC-S)               1
#           Kenilworth Square Apartments (KNW)    24
# Name: Date, dtype: int64

# %%
df_person.groupby(['OnOffCam'])['Date'].count()
# Out:
# OnOffCam
# 0     9
# 1    25
# Name: Date, dtype: int64
